# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler
df=pd.read_csv("Insurance_Vintage_Data.csv")
df.head()
# Out:
#        id Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0  381110   Male   25                1           11                   1
# 1  381111   Male   40                1           28                   0
# 2  381112   Male   47                1           28                   0
# 3  381113   Male   24                1           27                   1
# 4  381114   Male   27                1           28                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage
# 0    < 1 Year             No           35786                   152       53
# 1    1-2 Year            Yes           33762                     7      111
# 2    1-2 Year            Yes           40050                   124      199
# 3    < 1 Year            Yes           37356                   152      187
# 4    < 1 Year             No           59097                   152      297

# %%
df=pd.read_csv("Insurance_Vintage_Data.csv")
df. info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127037 entries, 0 to 127036
# Data columns (total 11 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    127037 non-null  int64
#  1   Gender                127037 non-null  object
#  2   Age                   127037 non-null  int64
#  3   Driving_License       127037 non-null  int64
#  4   Region_Code           127037 non-null  int64
#  5   Previously_Insured    127037 non-null  int64
#  6   Vehicle_Age           127037 non-null  object
#  7   Vehicle_Damage        127037 non-null  object
#  8   Annual_Premium        127037 non-null  int64
#  9   Policy_Sales_Channel  127037 non-null  int64
#  10  Vintage               127037 non-null  int64
# dtypes: int64(8), object(3)
# memory usage: 10.7+ MB

# %%
# converting Gender and Vehicle_Damage to Categorical Variables
import pandas as pd
df=pd.read_csv("Insurance_Vintage_Data.csv")
label_encoder=LabelEncoder()
df["Gender"]=label_encoder.fit_transform(df["Gender"])
df["Vehicle_Damage"]=label_encoder.fit_transform(df["Vehicle_Damage"])

# %%
# Convert Vehicle_Age to Numerical Variable
Vehicle_age_mapping={"< 1 Year":0,"1-2 Year":1,"> 2 Years": 2}
df["Vehicle_Age"]=df["Vehicle_Age"].map(Vehicle_age_mapping)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127037 entries, 0 to 127036
# Data columns (total 11 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    127037 non-null  int64
#  1   Gender                127037 non-null  object
#  2   Age                   127037 non-null  int64
#  3   Driving_License       127037 non-null  int64
#  4   Region_Code           127037 non-null  int64
#  5   Previously_Insured    127037 non-null  int64
#  6   Vehicle_Age           127037 non-null  int64
#  7   Vehicle_Damage        127037 non-null  object
#  8   Annual_Premium        127037 non-null  int64
#  9   Policy_Sales_Channel  127037 non-null  int64
#  10  Vintage               127037 non-null  int64
# dtypes: int64(9), object(2)
# memory usage: 10.7+ MB

# %%
df.head()
# Out:
#        id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0  381110       1   25                1           11                   1
# 1  381111       1   40                1           28                   0
# 2  381112       1   47                1           28                   0
# 3  381113       1   24                1           27                   1
# 4  381114       1   27                1           28                   1
#
#    Vehicle_Age  Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage
# 0            0               0           35786                   152       53
# 1            1               1           33762                     7      111
# 2            1               1           40050                   124      199
# 3            0               1           37356                   152      187
# 4            0               0           59097                   152      297

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler
df=pd.read_csv("Insurance_Vintage_Data.csv")
# Convert Vehicle_Age to Numerical Variable
Vehicle_age_mapping={"< 1 Year":0,"1-2 Year":1,"> 2 Years": 2}
df["Vehicle_Age"]=df["Vehicle_Age"].map(Vehicle_age_mapping)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127037 entries, 0 to 127036
# Data columns (total 11 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    127037 non-null  int64
#  1   Gender                127037 non-null  int32
#  2   Age                   127037 non-null  int64
#  3   Driving_License       127037 non-null  int64
#  4   Region_Code           127037 non-null  int64
#  5   Previously_Insured    127037 non-null  int64
#  6   Vehicle_Age           127037 non-null  int64
#  7   Vehicle_Damage        127037 non-null  int32
#  8   Annual_Premium        127037 non-null  int64
#  9   Policy_Sales_Channel  127037 non-null  int64
#  10  Vintage               127037 non-null  int64
# dtypes: int32(2), int64(9)
# memory usage: 9.7 MB

# %%
#Calculating mean annual premiums contributed by damaged and non-damaged vehicles
mean_premiums=df.groupby("Vehicle_Damage")["Annual_Premium"].mean()
print(mean_premiums)
# Out:
# Vehicle_Damage
# 0    30354.891839
# 1    30692.712023
# Name: Annual_Premium, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#Annotating mean on the plot
sns.boxplot(data =df, x="Vehicle_Damage", y="Annual_Premium")
plt.title("Annual Premium Vs Vehicle Damage")
plt.show()

# %%
sns.pairplot(df[["Vehicle_Age","Vehicle_Damage", "Annual_Premium","Vintage"]])
plt.show()
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
df=pd.read_csv("Insurance_Vintage_Data.csv")
from sklearn.preprocessing import LabelEncoder, StandardScaler
label_encoder=LabelEncoder()
df["Gender"]=label_encoder.fit_transform(df["Gender"])
df["Vehicle_Damage"]=label_encoder.fit_transform(df["Vehicle_Damage"])

# %%
df.head()
# Out:
#        id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0  381110       1   25                1           11                   1
# 1  381111       1   40                1           28                   0
# 2  381112       1   47                1           28                   0
# 3  381113       1   24                1           27                   1
# 4  381114       1   27                1           28                   1
#
#    Vehicle_Age  Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage
# 0            0               0           35786                   152       53
# 1            1               1           33762                     7      111
# 2            1               1           40050                   124      199
# 3            0               1           37356                   152      187
# 4            0               0           59097                   152      297

# %%
# Convert Vehicle_Age to Numerical Variable
Vehicle_age_mapping={"< 1 Year":0,"1-2 Year":1,"> 2 Years": 2}
df["Vehicle_Age"]=df["Vehicle_Age"].map(Vehicle_age_mapping)

# %%
# converting Gender and Vehicle_Damage to Categorical Variables
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("Insurance_Vintage_Data.csv")

# Convert Vehicle_Age to Numerical Variable
Vehicle_age_mapping={"< 1 Year":0,"1-2 Year":1,"> 2 Years": 2}
df["Vehicle_Age"]=df["Vehicle_Age"].map(Vehicle_age_mapping)

label_encoder=LabelEncoder()
df["Gender"]=label_encoder.fit_transform(df["Gender"])
df["Vehicle_Damage"]=label_encoder.fit_transform(df["Vehicle_Damage"])
# Computing Correlation
selected_cols = ["Vehicle_Age", "Vehicle_Damage", "Annual_Premium", "Policy_Sales_Channel", "Vintage"]
corr = df[selected_cols].corr()
print(corr)
# Plot
df_corr = df[[ 'Vehicle_Age', 'Driving_License',  'Previously_Insured', 'Annual_Premium', 'Vintage', 'Region_Code']]
sns.heatmap(df_corr.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()
# Out:
#                       Vehicle_Age  Vehicle_Damage  Annual_Premium  \
# Vehicle_Age              1.000000        0.388043        0.051895
# Vehicle_Damage           0.388043        1.000000        0.009968
# Annual_Premium           0.051895        0.009968        1.000000
# Policy_Sales_Channel    -0.491513       -0.230298       -0.116452
# Vintage                  0.002299        0.001879       -0.001607
#
#                       Policy_Sales_Channel   Vintage
# Vehicle_Age                      -0.491513  0.002299
# Vehicle_Damage                   -0.230298  0.001879
# Annual_Premium                   -0.116452 -0.001607
# Policy_Sales_Channel              1.000000 -0.003257
# Vintage                          -0.003257  1.000000

# %%
df.head()
# Out:
#        id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0  381110       1   25                1           11                   1
# 1  381111       1   40                1           28                   0
# 2  381112       1   47                1           28                   0
# 3  381113       1   24                1           27                   1
# 4  381114       1   27                1           28                   1
#
#    Vehicle_Age  Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage
# 0            0               0           35786                   152       53
# 1            1               1           33762                     7      111
# 2            1               1           40050                   124      199
# 3            0               1           37356                   152      187
# 4            0               0           59097                   152      297

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127037 entries, 0 to 127036
# Data columns (total 11 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    127037 non-null  int64
#  1   Gender                127037 non-null  int32
#  2   Age                   127037 non-null  int64
#  3   Driving_License       127037 non-null  int64
#  4   Region_Code           127037 non-null  int64
#  5   Previously_Insured    127037 non-null  int64
#  6   Vehicle_Age           127037 non-null  int64
#  7   Vehicle_Damage        127037 non-null  int32
#  8   Annual_Premium        127037 non-null  int64
#  9   Policy_Sales_Channel  127037 non-null  int64
#  10  Vintage               127037 non-null  int64
# dtypes: int32(2), int64(9)
# memory usage: 9.7 MB

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# Load data
df = pd.read_csv("Insurance_Vintage_Data.csv")

# Drop ID and Region_Code (not useful for clustering)
df = df.drop(columns=["id", "Region_Code"])

# Encode categorical variables
df['Gender'] = df['Gender'].map({'Male': 1, 'Female': 0})
df['Vehicle_Damage'] = df['Vehicle_Damage'].map({'Yes': 1, 'No': 0})
df['Vehicle_Age'] = df['Vehicle_Age'].map({'< 1 Year': 0, '1-2 Year': 1, '> 2 Years': 2})

# Select features
X = df.drop(columns=['Cluster'], errors='ignore')  

# Scale numeric features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Apply KMeans clustering
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
df['Cluster'] = kmeans.fit_predict(X_scaled)

# View cluster summary
cluster_summary = df.groupby("Cluster").mean(numeric_only=True)
print(cluster_summary)
# Out:
#            Gender        Age  Driving_License  Previously_Insured  \
# Cluster
# 0        0.444387  27.821050         0.999959            0.926488
# 1        0.633292  54.420917         0.994300            0.311164
# 2        0.551586  35.704332         1.000000            0.016963
#
#          Vehicle_Age  Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  \
# Cluster
# 0           0.171473        0.027951    29944.862060            146.974377
# 1           1.104077        0.647675    34687.048146             46.291955
# 2           0.630522        0.960196    26674.104488            138.456680
#
#             Vintage
# Cluster
# 0        153.961421
# 1        154.782241
# 2        154.269955

# %%
# Company may consider rewarding  low-risk clients with high vintage by offering loyalty points as a retention  incetive,
#Upselling or crossselling new products that are client-centered  
# The premium charged is also quite high for such low-risk and long term clients:company to  offer dicounts to reduce possibility of churn
to other companies
# premiums to be charged based on potential risk,some of the  high-risk clients are undercharged
#Company to review pricing models to ensure alignment with damage history, driving behaviour, and vehicle age 
# Company to consider tapping into new markets_the uninsured customers by launching acquistion campaigns such as offering affordable entry plans,
leveraging easy to use onboarding digital platforms.

# %%
print(df['Cluster'].value_counts())
# Out:
# Cluster
# 1    63436
# 0    63364
# 2      237
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x="Cluster", y="Annual_Premium", data=df)
plt.title("Annual Premium Distribution by Cluster")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.barplot(x="Cluster", y="Age", data=df, estimator='mean')
plt.title("Average Age by Cluster")
plt.show()
